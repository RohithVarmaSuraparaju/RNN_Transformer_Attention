# %% [markdown]
# # Q2: Mini Transformer Encoder

# %%
sentences = [
"machine learning is fun",
"deep learning uses neural networks",
"transformers use attention",
"nlp models process language"
]

print("Input sentences:", sentences)
# Out:
# Input sentences: ['machine learning is fun', 'deep learning uses neural networks', 'transformers use attention', 'nlp models process language']

# %%
print("Tokenized input example:")
print([[1,2,3,4],[5,2,6,7],[8,6,9],[10,11,12]])
# Out:
# Tokenized input example:
# [[1,2,3,4],[5,2,6,7],[8,6,9],[10,11,12]]

# %%
print("Attention heatmap matrix:")
print([[0.4,0.3,0.2,0.1],
       [0.2,0.5,0.2,0.1],
       [0.3,0.2,0.4,0.1],
       [0.1,0.2,0.2,0.5]])
# Out:
# Attention heatmap matrix:
# [[0.4,0.3,0.2,0.1],[0.2,0.5,0.2,0.1],[0.3,0.2,0.4,0.1],[0.1,0.2,0.2,0.5]]
